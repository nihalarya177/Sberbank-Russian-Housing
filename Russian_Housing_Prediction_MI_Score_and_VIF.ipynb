# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
import statsmodels.api as sm

from math import ceil
from sklearn.linear_model import LinearRegression
from sklearn.feature_selection import mutual_info_regression
from sklearn.feature_selection import SelectPercentile as SP
from xgboost import XGBRegressor
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as MSE
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import GradientBoostingRegressor, RandomForestRegressor
from xgboost import XGBRegressor
from sklearn.model_selection import GridSearchCV
import statsmodels.api as sm
from statsmodels.stats.outliers_influence import variance_inflation_factor
from tqdm import tqdm

# %%
df = pd.read_csv('train.csv', index_col = 'id')

X_test = pd.read_csv('test.csv', index_col='id')

# Dropping the rows which have missing prediction values
df = df.dropna(axis=0, subset=['price_doc'])

y_train = df.price_doc
X_train = df.drop(['price_doc'], axis = 1)

# %%
def null_values(X_train, X_test):
    null_train = X_train.isnull().sum()
    null_test = X_test.isnull().sum()
    
    df_dict = {'Train Data': null_train,
                'Test Data': null_test}
    null_df = pd.DataFrame(df_dict)
    
    null_df = null_df.loc[(null_df['Train Data']!=0) | (null_df['Test Data']!=0)]
    null_df = null_df.sort_values(by=['Train Data','Test Data'],ascending=False)
    
    return null_df

# %%
null_vals = null_values(X_train, X_test)
null_vals
# Out:
#                                        Train Data  Test Data
# hospital_beds_raion                         14441       3418
# build_year                                  13605       1049
# state                                       13559        694
# cafe_sum_500_min_price_avg                  13281       3159
# cafe_sum_500_max_price_avg                  13281       3159
# cafe_avg_price_500                          13281       3159
# max_floor                                    9572          0
# material                                     9572          0
# num_room                                     9572          0
# kitch_sq                                     9572          0
# preschool_quota                              6688       1596
# school_quota                                 6685       1595
# cafe_sum_1000_min_price_avg                  6524       1222
# cafe_sum_1000_max_price_avg                  6524       1222
# cafe_avg_price_1000                          6524       1222
# life_sq                                      6383       1176
# raion_build_count_with_material_info         4991       1218
# build_count_block                            4991       1218
# build_count_wood                             4991       1218
# build_count_frame                            4991       1218
# build_count_brick                            4991       1218
# build_count_monolith                         4991       1218
# build_count_panel                            4991       1218
# build_count_foam                             4991       1218
# build_count_slag                             4991       1218
# build_count_mix                              4991       1218
# raion_build_count_with_builddate_info        4991       1218
# build_count_before_1920                      4991       1218
# build_count_1921-1945                        4991       1218
# build_count_1946-1970                        4991       1218
# build_count_1971-1995                        4991       1218
# build_count_after_1995                       4991       1218
# cafe_sum_1500_min_price_avg                  4199        821
# cafe_sum_1500_max_price_avg                  4199        821
# cafe_avg_price_1500                          4199        821
# cafe_sum_2000_min_price_avg                  1725        424
# cafe_sum_2000_max_price_avg                  1725        424
# cafe_avg_price_2000                          1725        424
# cafe_sum_3000_min_price_avg                   991        182
# cafe_sum_3000_max_price_avg                   991        182
# cafe_avg_price_3000                           991        182
# cafe_sum_5000_min_price_avg                   297        128
# cafe_sum_5000_max_price_avg                   297        128
# cafe_avg_price_5000                           297        128
# prom_part_5000                                178         92
# floor                                         167          0
# metro_min_walk                                 25         34
# metro_km_walk                                  25         34
# railroad_station_walk_km                       25         34
# railroad_station_walk_min                      25         34
# ID_railroad_station_walk                       25         34
# product_type                                    0         33
# green_part_2000                                 0         19

# %%
drop_cols = null_vals.index.values.tolist()

# %%
df = df.drop(columns=drop_cols)

# %%
categorical_features = list(df.select_dtypes('object').columns)

# Casting to category datatype
for name in categorical_features:
    df[name] = df[name].astype("category")
    
    # Add a None category for missing values
    if "None" not in df[name].cat.categories:
        df[name] = df[name].cat.add_categories("None")

# %%
# Label encoding for categoricals
for colname in df.select_dtypes(["category"]):
    df[colname] = df[colname].cat.codes

# %%
df.dtypes.value_counts()
# Out:
# int64      156
# float64     67
# int8        13
# int16        2
# dtype: int64

# %%
y_train = df.price_doc
X_train = df.drop(['price_doc'], axis = 1)

# %%
def make_mi_scores(X, y):
    X = X.copy()
    # All discrete features should now have integer dtypes
    # discrete_features = [pd.api.types.is_integer_dtype(t) for t in X.dtypes]
    mi_scores = mutual_info_regression(X.select_dtypes('number'), y, random_state=0)
    mi_scores = pd.DataFrame(mi_scores.round(2), columns=["MI_Scores"], index=X.select_dtypes('number').columns)
    return mi_scores

# %%
mi_scores = make_mi_scores(X_train, y_train)
linear_corr = pd.DataFrame(X_train.corrwith(y_train).round(2), columns=['Lin_Correlation'])

corr_with_price = pd.concat([mi_scores, linear_corr], axis=1)
corr_with_price = corr_with_price.sort_values('MI_Scores',ascending=False)

def feature_selector(i, data):

    selected_features = []

    for row in corr_with_price.head(i).index:
        print(row)
        selected_features.append(''+row)
    X_model = pd.DataFrame(data).loc[:,selected_features]
    
    return X_model

# %%
corr_with_price
# Out:
#                                        MI_Scores  Lin_Correlation
# full_sq                                     0.71             0.34
# sub_area                                    0.59            -0.09
# 0_17_male                                   0.58             0.14
# 0_13_all                                    0.58             0.14
# work_all                                    0.58             0.14
# young_female                                0.58             0.14
# young_all                                   0.58             0.14
# 0_6_female                                  0.58             0.13
# 7_14_male                                   0.58             0.14
# 7_14_female                                 0.58             0.14
# work_female                                 0.58             0.14
# 0_17_female                                 0.58             0.14
# work_male                                   0.58             0.15
# 0_13_male                                   0.58             0.14
# raion_popul                                 0.58             0.15
# 0_13_female                                 0.58             0.14
# 0_6_male                                    0.57             0.13
# 16_29_male                                  0.57             0.02
# young_male                                  0.57             0.14
# female_f                                    0.57             0.02
# full_all                                    0.57             0.03
# ekder_all                                   0.57             0.17
# ekder_female                                0.57             0.17
# 0_6_all                                     0.57             0.13
# ekder_male                                  0.57             0.18
# 7_14_all                                    0.57             0.14
# children_preschool                          0.57             0.13
# 0_17_all                                    0.57             0.14
# children_school                             0.57             0.14
# male_f                                      0.56             0.03
# green_zone_part                             0.56            -0.09
# 16_29_all                                   0.56             0.02
# area_m                                      0.56            -0.17
# 16_29_female                                0.56             0.02
# indust_part                                 0.55            -0.08
# ID_railroad_station_avto                    0.52            -0.05
# ID_metro                                    0.50             0.05
# trc_sqm_5000                                0.50             0.27
# sadovoe_km                                  0.49            -0.28
# ttk_km                                      0.49            -0.27
# kremlin_km                                  0.49            -0.28
# zd_vokzaly_avto_km                          0.49            -0.28
# bulvar_ring_km                              0.49            -0.28
# workplaces_km                               0.48            -0.21
# preschool_km                                0.48            -0.14
# basketball_km                               0.48            -0.22
# thermal_power_plant_km                      0.47            -0.21
# oil_chemistry_km                            0.47            -0.12
# cafe_count_5000                             0.47             0.23
# detention_facility_km                       0.47            -0.22
# stadium_km                                  0.47            -0.24
# school_km                                   0.47            -0.15
# trc_count_5000                              0.47             0.29
# nuclear_reactor_km                          0.47            -0.26
# catering_km                                 0.46            -0.21
# kindergarten_km                             0.46            -0.14
# power_transmission_line_km                  0.46            -0.16
# exhibition_km                               0.46            -0.21
# metro_km_avto                               0.46            -0.18
# cafe_count_3000                             0.46             0.15
# sport_count_5000                            0.46             0.29
# university_km                               0.46            -0.22
# sport_count_3000                            0.46             0.29
# cafe_count_5000_price_1000                  0.46             0.24
# radiation_km                                0.46            -0.19
# big_church_km                               0.45            -0.19
# office_km                                   0.45            -0.22
# swim_pool_km                                0.45            -0.21
# incineration_km                             0.45            -0.06
# office_sqm_5000                             0.45             0.27
# metro_min_avto                              0.45            -0.19
# fitness_km                                  0.44            -0.19
# ID_big_road2                                0.44            -0.08
# shopping_centers_km                         0.44            -0.18
# hospice_morgue_km                           0.44            -0.15
# public_healthcare_km                        0.44            -0.17
# trc_sqm_3000                                0.44             0.23
# mkad_km                                     0.44            -0.02
# theater_km                                  0.44            -0.22
# cafe_count_5000_price_1500                  0.44             0.23
# cafe_count_5000_price_500                   0.44             0.23
# museum_km                                   0.44            -0.20
# park_km                                     0.44            -0.19
# mosque_km                                   0.43            -0.17
# cafe_count_3000_price_1000                  0.43             0.17
# ts_km                                       0.43            -0.16
# green_part_5000                             0.42            -0.16
# ice_rink_km                                 0.42            -0.15
# trc_count_3000                              0.42             0.24
# cafe_count_2000                             0.42             0.12
# market_shop_km                              0.42            -0.17
# water_treatment_km                          0.42             0.05
# additional_education_km                     0.42            -0.15
# railroad_station_avto_min                   0.42            -0.14
# public_transport_station_km                 0.42            -0.12
# bus_terminal_avto_km                        0.42            -0.16
# public_transport_station_min_walk           0.42            -0.12
# sport_count_2000                            0.41             0.28
# prom_part_3000                              0.41             0.02
# ID_big_road1                                0.41            -0.07
# railroad_station_avto_km                    0.41            -0.13
# cafe_count_3000_price_1500                  0.41             0.15
# green_part_3000                             0.41            -0.14
# railroad_km                                 0.41            -0.09
# big_road2_km                                0.40            -0.16
# cafe_count_3000_price_500                   0.40             0.15
# big_church_count_5000                       0.40             0.20
# big_market_km                               0.40            -0.05
# cafe_count_1500                             0.40             0.11
# church_synagogue_km                         0.39            -0.12
# green_part_1500                             0.39            -0.08
# big_road1_km                                0.39            -0.10
# cemetery_km                                 0.39            -0.02
# cafe_count_5000_na_price                    0.39             0.23
# cafe_count_5000_price_2500                  0.39             0.23
# church_count_5000                           0.39             0.21
# cafe_count_2000_price_1000                  0.38             0.13
# office_count_5000                           0.38             0.22
# sport_objects_raion                         0.38             0.25
# green_part_1000                             0.38            -0.06
# cafe_count_2000_price_1500                  0.37             0.12
# sport_count_1500                            0.37             0.26
# trc_sqm_2000                                0.37             0.14
# water_km                                    0.37            -0.03
# ID_bus_terminal                             0.37            -0.05
# school_education_centers_raion              0.37             0.19
# industrial_km                               0.37             0.05
# green_zone_km                               0.36            -0.06
# prom_part_2000                              0.36            -0.05
# preschool_education_centers_raion           0.36             0.16
# prom_part_1500                              0.35            -0.07
# cafe_count_1000                             0.35             0.11
# cafe_count_2000_price_500                   0.35             0.12
# trc_count_2000                              0.35             0.18
# church_count_3000                           0.34             0.14
# office_sqm_3000                             0.34             0.23
# market_count_5000                           0.34             0.19
# cafe_count_1500_price_1000                  0.33             0.13
# big_church_count_3000                       0.33             0.13
# office_count_3000                           0.32             0.16
# cafe_count_1500_price_1500                  0.32             0.11
# cafe_count_3000_price_2500                  0.32             0.15
# cafe_count_3000_na_price                    0.31             0.16
# ecology                                     0.31             0.04
# green_part_500                              0.31            -0.05
# prom_part_1000                              0.31            -0.06
# trc_sqm_1500                                0.30             0.09
# trc_count_1500                              0.29             0.15
# cafe_count_1500_price_500                   0.29             0.11
# office_sqm_2000                             0.29             0.22
# leisure_count_5000                          0.28             0.20
# sport_count_1000                            0.28             0.20
# cafe_count_5000_price_4000                  0.27             0.21
# shopping_centers_raion                      0.27             0.15
# office_count_2000                           0.27             0.15
# cafe_count_2000_na_price                    0.25             0.12
# cafe_count_2000_price_2500                  0.25             0.12
# cafe_count_1000_price_1000                  0.25             0.16
# prom_part_500                               0.24            -0.01
# market_count_3000                           0.24             0.15
# cafe_count_1000_price_1500                  0.24             0.12
# office_sqm_1500                             0.24             0.20
# office_raion                                0.24             0.15
# office_count_1500                           0.22             0.16
# church_count_2000                           0.22             0.09
# ID_railroad_terminal                        0.21             0.08
# cafe_count_1000_price_500                   0.21             0.08
# additional_education_raion                  0.21             0.06
# big_church_count_2000                       0.21             0.08
# trc_sqm_1000                                0.21             0.04
# cafe_count_500                              0.20             0.12
# cafe_count_1500_price_2500                  0.20             0.12
# leisure_count_3000                          0.19             0.11
# healthcare_centers_raion                    0.19             0.19
# cafe_count_1500_na_price                    0.17             0.12
# church_count_1500                           0.17             0.08
# big_church_count_1500                       0.17             0.07
# trc_count_1000                              0.17             0.08
# cafe_count_3000_price_4000                  0.16             0.13
# market_count_2000                           0.16             0.11
# office_sqm_1000                             0.16             0.16
# office_count_1000                           0.14             0.18
# leisure_count_2000                          0.13             0.08
# cafe_count_5000_price_high                  0.13             0.21
# cafe_count_1000_price_2500                  0.13             0.09
# sport_count_500                             0.12             0.09
# cafe_count_500_price_1000                   0.12             0.18
# cafe_count_1000_na_price                    0.12             0.11
# cafe_count_2000_price_4000                  0.11             0.09
# cafe_count_500_price_1500                   0.11             0.15
# church_count_1000                           0.11             0.05
# big_church_count_1000                       0.10             0.09
# cafe_count_500_price_500                    0.10             0.09
# market_count_1500                           0.10             0.08
# incineration_raion                          0.09            -0.08
# leisure_count_1500                          0.09             0.12
# office_count_500                            0.09             0.19
# radiation_raion                             0.08             0.12
# cafe_count_1500_price_4000                  0.08             0.06
# trc_count_500                               0.08             0.06
# office_sqm_500                              0.07             0.13
# mosque_count_5000                           0.07             0.18
# cafe_count_3000_price_high                  0.07             0.16
# timestamp                                   0.07             0.12
# trc_sqm_500                                 0.07             0.00
# cafe_count_500_price_2500                   0.06             0.08
# market_count_1000                           0.06             0.07
# church_count_500                            0.06             0.01
# mosque_count_3000                           0.06             0.10
# cafe_count_1000_price_4000                  0.05             0.04
# cafe_count_2000_price_high                  0.05             0.12
# leisure_count_1000                          0.05             0.10
# big_church_count_500                        0.05             0.03
# cafe_count_500_na_price                     0.05             0.05
# cafe_count_1500_price_high                  0.04             0.13
# big_market_raion                            0.04            -0.08
# university_top_20_raion                     0.04             0.17
# water_1line                                 0.03            -0.04
# culture_objects_top_25_raion                0.03             0.04
# culture_objects_top_25                      0.02             0.16
# school_education_centers_top_20_raion       0.02             0.10
# market_count_500                            0.02             0.04
# cafe_count_1000_price_high                  0.02             0.17
# cafe_count_500_price_4000                   0.02             0.07
# mosque_count_1500                           0.01             0.11
# cafe_count_500_price_high                   0.01             0.05
# mosque_count_1000                           0.01             0.09
# railroad_1line                              0.01            -0.03
# big_road1_1line                             0.01             0.06
# thermal_power_plant_raion                   0.01             0.03
# mosque_count_2000                           0.01             0.10
# oil_chemistry_raion                         0.01            -0.02
# leisure_count_500                           0.01             0.16
# railroad_terminal_raion                     0.01             0.06
# nuclear_reactor_raion                       0.01             0.03
# detention_facility_raion                    0.01             0.04
# mosque_count_500                            0.00             0.02

# %%
top = sum(corr_with_price.MI_Scores>0.1)

# %%
X_model = feature_selector(top, X_train)
# Out:
# full_sq
# sub_area
# 0_17_male
# 0_13_all
# work_all
# young_female
# young_all
# 0_6_female
# 7_14_male
# 7_14_female
# work_female
# 0_17_female
# work_male
# 0_13_male
# raion_popul
# 0_13_female
# 0_6_male
# 16_29_male
# young_male
# female_f
# full_all
# ekder_all
# ekder_female
# 0_6_all
# ekder_male
# 7_14_all
# children_preschool
# 0_17_all
# children_school
# male_f
# green_zone_part
# 16_29_all
# area_m
# 16_29_female
# indust_part
# ID_railroad_station_avto
# ID_metro
# trc_sqm_5000
# sadovoe_km
# ttk_km
# kremlin_km
# zd_vokzaly_avto_km
# bulvar_ring_km
# workplaces_km
# preschool_km
# basketball_km
# thermal_power_plant_km
# oil_chemistry_km
# cafe_count_5000
# detention_facility_km
# stadium_km
# school_km
# trc_count_5000
# nuclear_reactor_km
# catering_km
# kindergarten_km
# power_transmission_line_km
# exhibition_km
# metro_km_avto
# cafe_count_3000
# sport_count_5000
# university_km
# sport_count_3000
# cafe_count_5000_price_1000
# radiation_km
# big_church_km
# office_km
# swim_pool_km
# incineration_km
# office_sqm_5000
# metro_min_avto
# fitness_km
# ID_big_road2
# shopping_centers_km
# hospice_morgue_km
# public_healthcare_km
# trc_sqm_3000
# mkad_km
# theater_km
# cafe_count_5000_price_1500
# cafe_count_5000_price_500
# museum_km
# park_km
# mosque_km
# cafe_count_3000_price_1000
# ts_km
# green_part_5000
# ice_rink_km
# trc_count_3000
# cafe_count_2000
# market_shop_km
# water_treatment_km
# additional_education_km
# railroad_station_avto_min
# public_transport_station_km
# bus_terminal_avto_km
# public_transport_station_min_walk
# sport_count_2000
# prom_part_3000
# ID_big_road1
# railroad_station_avto_km
# cafe_count_3000_price_1500
# green_part_3000
# railroad_km
# big_road2_km
# cafe_count_3000_price_500
# big_church_count_5000
# big_market_km
# cafe_count_1500
# church_synagogue_km
# green_part_1500
# big_road1_km
# cemetery_km
# cafe_count_5000_na_price
# cafe_count_5000_price_2500
# church_count_5000
# cafe_count_2000_price_1000
# office_count_5000
# sport_objects_raion
# green_part_1000
# cafe_count_2000_price_1500
# sport_count_1500
# trc_sqm_2000
# water_km
# ID_bus_terminal
# school_education_centers_raion
# industrial_km
# green_zone_km
# prom_part_2000
# preschool_education_centers_raion
# prom_part_1500
# cafe_count_1000
# cafe_count_2000_price_500
# trc_count_2000
# church_count_3000
# office_sqm_3000
# market_count_5000
# cafe_count_1500_price_1000
# big_church_count_3000
# office_count_3000
# cafe_count_1500_price_1500
# cafe_count_3000_price_2500
# cafe_count_3000_na_price
# ecology
# green_part_500
# prom_part_1000
# trc_sqm_1500
# trc_count_1500
# cafe_count_1500_price_500
# office_sqm_2000
# leisure_count_5000
# sport_count_1000
# cafe_count_5000_price_4000
# shopping_centers_raion
# office_count_2000
# cafe_count_2000_na_price
# cafe_count_2000_price_2500
# cafe_count_1000_price_1000
# prom_part_500
# market_count_3000
# cafe_count_1000_price_1500
# office_sqm_1500
# office_raion
# office_count_1500
# church_count_2000
# ID_railroad_terminal
# cafe_count_1000_price_500
# additional_education_raion
# big_church_count_2000
# trc_sqm_1000
# cafe_count_500
# cafe_count_1500_price_2500
# leisure_count_3000
# healthcare_centers_raion
# cafe_count_1500_na_price
# church_count_1500
# big_church_count_1500
# trc_count_1000
# cafe_count_3000_price_4000
# market_count_2000
# office_sqm_1000
# office_count_1000
# leisure_count_2000
# cafe_count_5000_price_high
# cafe_count_1000_price_2500
# sport_count_500
# cafe_count_500_price_1000
# cafe_count_1000_na_price
# cafe_count_2000_price_4000
# cafe_count_500_price_1500
# church_count_1000

# %%
VIF = df.copy()


for i in tqdm(range(300)):
    X = VIF[list(X_model.columns)]
    vif_info = pd.DataFrame()
    vif_info['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif_info['Column'] = X.columns
    vif_info.reset_index(ascending=False, inplace=True)
    vif_info.reset_index(inplace=True)
    vif_info.drop(columns=['index'], inplace=True)
    vif = vif_info['VIF'][0]
    print(vif)
    drop_var = vif_info['Column'][0]
    if vif>5:
        X_model.drop(columns=[drop_var], inplace=True)
    if vif<=8:
        break
# Out:
#   0%|                                                                                          | 0/300 [00:00<?, ?it/s]C:\Users\nihal\anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#   0%|                                                                                          | 0/300 [07:13<?, ?it/s]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-153-dc955839acd9> in <module>
#       7     vif_info['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
#       8     vif_info['Column'] = X.columns
# ----> 9     vif_info.reset_index(ascending=False, inplace=True)
#      10     vif_info.reset_index(inplace=True)
#      11     vif_info.drop(columns=['index'], inplace=True)
#
# TypeError: reset_index() got an unexpected keyword argument 'ascending'
